# %%
import wbgapi as wb
import pandas as pd
import os

# %%
wb.topic.Series() #listar todos os topicos presentes no World Bank
# Out:
# 1     Agriculture & Rural Development
# 2                   Aid Effectiveness
# 3                    Economy & Growth
# 4                           Education
# 5                     Energy & Mining
# 6                         Environment
# 7                    Financial Sector
# 8                              Health
# 9                      Infrastructure
# 10          Social Protection & Labor
# 11                            Poverty
# 12                     Private Sector
# 13                      Public Sector
# 14               Science & Technology
# 15                 Social Development
# 16                  Urban Development
# 17                             Gender
# 18        Millenium development goals
# 19                     Climate Change
# 20                      External Debt
# 21                              Trade
# Name: TopicName, dtype: object

# %%
topics = [{'id': '1',
  'value': 'Agriculture & Rural Development',
  'dir': 'acriculture_rural_development'},

  {'id': '3',
  'value': 'Economy & Growth',
  'dir': 'economy_growth'},

  {'id': '5',
  'value': 'Energy & Mining',
  'dir': 'energy_mining'},

 {'id': '6',
  'value': 'Environment',
  'dir': 'environment'},

  {'id': '19',
   'value': 'Climate Change',
   'dir': 'climate_change'}]

topics_df = pd.DataFrame(topics, columns=['id', 'value', 'dir'])
topics_df
# Out:
#    id                            value                            dir
# 0   1  Agriculture & Rural Development  acriculture_rural_development
# 1   3                 Economy & Growth                 economy_growth
# 2   5                  Energy & Mining                  energy_mining
# 3   6                      Environment                    environment
# 4  19                   Climate Change                 climate_change

# %% [markdown]
# member(1) - Agriculture & Rural Development
# - AG.LND.AGRI.ZS	Agricultural land (% of land area)
# - AG.AGR.TRAC.NO	Agricultural machinery, tractors
#
# memeber(3) - Economy & Growth
# - NY.GDP.MKTP.KD.ZG	GDP growth (annual %)
# - PA.NUS.PPP	PPP conversion factor, GDP
#
# member(5) - Energy & Mining
# - EG.USE.COMM.FO.ZS	Fossil fuel energy consumption
# - EG.USE.COMM.CL.ZS	Alternative and nuclear energy (% of total energy use)
#
# member(6) - Environment
# - EG.CFT.ACCS.ZS	Access to clean fuels and technologies for cooking
# - AG.LND.FRST.ZS	Forest area (% of land area)
#
# member(19) - Climate Change
# - EN.ATM.CO2E.PC	CO2 emissions (metric tons per capita) # label

# %%
wb.series.info(wb.topic.members(15))
# Out:
# id                      value
# ----------------------  -------------------------------------------------------------------------------------------------
# SP.ADO.TFRT             Adolescent fertility rate (births per 1,000 women ages 15-19)
# SL.TLF.0714.FE.ZS       Children in employment, female (% of female children ages 7-14)
# SL.TLF.0714.MA.ZS       Children in employment, male (% of male children ages 7-14)
# SL.TLF.0714.SW.ZS       Children in employment, study and work (% of children in employment, ages 7-14)
# SL.TLF.0714.SW.FE.ZS    Children in employment, study and work, female (% of female children in employment, ages 7-14)
# SL.TLF.0714.SW.MA.ZS    Children in employment, study and work, male (% of male children in employment, ages 7-14)
# SL.TLF.0714.ZS          Children in employment, total (% of children ages 7-14)
# SL.TLF.0714.WK.ZS       Children in employment, work only (% of children in employment, ages 7-14)
# ...

# %%
wb.data.DataFrame('SP.ADO.TFRT', list(wb.economy.Series().index), time = range(1950,2024))
# Out:
#              YR1960      YR1961      YR1962      YR1963      YR1964  \
# economy
# ABW       62.182000   61.589000   61.170000   59.658000   58.324000
# AFE      140.180526  140.810248  141.664168  142.324951  143.456933
# AFG      138.876000  138.717000  138.494000  138.173000  140.107000
# AFW      167.054250  170.748419  174.212286  175.665650  175.847602
# AGO      148.279000  150.275000  150.801000  153.002000  155.661000
# ...             ...         ...         ...         ...         ...
# XKX       81.772000   82.849000   82.555000   81.527000   80.337000
# YEM      142.832000  144.901000  146.197000  145.273000  145.403000
# ZAF      101.605000  101.186000  101.666000  101.630000  101.854000
# ZMB      184.021000  185.311000  186.542000  187.872000  188.592000
# ZWE      168.191000  167.318000  165.582000  163.887000  157.860000
#
#              YR1965      YR1966      YR1967      YR1968      YR1969  ...  \
# ...

# %%
wb.data.DataFrame('NY.GDP.PCAP.PP.KD', list(wb.economy.Series().index), time = range(1990,2024))
# Out:
#                YR1990        YR1991        YR1992        YR1993        YR1994  \
# economy
# ABW      32278.868539  33744.108798  34544.060647  35957.815973  37683.917709
# AFE       3045.457644   2963.585471   2831.236489   2744.839315   2722.151263
# AFG               NaN           NaN           NaN           NaN           NaN
# AFW       2790.264157   2752.715449   2745.707708   2646.355086   2576.747600
# AGO       5793.084512   5659.119330   5158.383835   3799.194899   3728.886199
# ...               ...           ...           ...           ...           ...
# XKX               NaN           NaN           NaN           NaN           NaN
# YEM               NaN           NaN           NaN           NaN           NaN
# ZAF      10391.964137  10026.325862   9612.392874   9555.986762   9692.535766
# ZMB       2290.039226   2232.837441   2141.504615   2232.710379   1991.185925
# ZWE       2704.757299   2781.787843   2468.278257   2458.783255   2670.106615
#
# ...

# %%
for item in list(wb.series.info(wb.topic.members(15)).items):
    print(item['id'], item['value'])
    df_save = wb.data.DataFrame(item['id'], list(wb.economy.Series().index), time = range(1950,2024))
    df_save.to_csv(f'data/{item["id"]}.csv')
